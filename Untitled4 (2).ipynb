# %%
#IMPORT NECESSARY LIBRARIES
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#LOAD DATA
data = pd.read_csv("C:/Users/JULIANA/Downloads/Download Data csv retina (1).csv")
data.head()
# Out:
#                      Timestamp what is your visual acuity  \
# 0  2024/06/04 7:12:42 PM GMT+3                        NaN
# 1  2024/07/11 6:25:15 PM GMT+3                        NaN
# 2  2024/07/11 6:33:16 PM GMT+3                        NaN
# 3  2024/07/11 7:56:36 PM GMT+3                        NaN
# 4  2024/07/11 8:33:01 PM GMT+3                        NaN
#
#   What difficulties in seeing do u have             need  peripheral vision  \
# 0                                   NaN  assistive device          Option 1
# 1                                   NaN               job               NaN
# 2                                   NaN     work training               NaN
# 3                                   NaN  assistive device          Option 1
# 4                                   NaN  assistive device          Option 1
#
#    gender                   level of education  \
# 0     NaN                  Bachelor Abschluss
# 1     NaN  Bachelor's degree in Arts Education
# 2     NaN                          University
# 3     NaN                          University
# 4     NaN                        Undergraduate
#
#   consent to share information with funders and research institutes  \
# 0                                      Yes I consent
# 1                                       I do consent
# 2                                         I consent
# 3                                                Yes
# 4                                                Yes
#
#   challenges in job search and mobility  \
# 0                              Option 1
# 1                              Option 1
# 2                              Option 1
# 3                              Option 1
# 4                              Option 1
#
#   when do you have issues adjusting light  ...       age               Name  \
# 0                                     NaN  ...  20 to 30    Anita Atuheire
# 1                                     NaN  ...  20 to 30     Sangalo Dianah
# 2                                     NaN  ...  20 to 30  Atim Nelly Marie
# 3                                     NaN  ...  20 to 30    Openda Hillary
# 4                                     NaN  ...  20 to 30  Kiwanda uthaifah
#
#                           Email                           Address  \
# 0         anita37desa@gmail.com             Schäufeleinstraße 26a
# 1      sangalodianah2@gmail.com                      Bombo Kalule
# 2      nellymarieatim@gmail.com          Currently in Nakasongola
# 3     opendahillary89@gmail.com  Ocwee memorial hostel, Gulu city
# 4  kiwandauthaifah483@gmail.com                            Gulu.
#
#   Phone number Comments please add your measurements here from the doctors  \
# 0   5218061474                                                NaN
# 1    777744959                         Need your support and help
# 2   O760074203  I thank you for this but please I would like t...
# 3    756998432                                              None
# 4    759894923  Disease condition is keratoconus with myopia.\...
#
#   Unnamed: 24 Unnamed: 25           Unnamed: 26           Unnamed: 27
# 0    Stundent    Student       retinal dystophy                 other
# 1         NaN     Teacher  retinitis pigmentosa   impairement  degree
# 2    Teacher      Teacher  retinitis pigmentosa  visual acuity degree
# 3    Student     Student   retinitis pigmentosa  visual acuity degree
# 4    Student      Student                   NaN  visual acuity degree
#
# [5 rows x 28 columns]

# %%
# Renaming 'Name' to 'Full Name' and 'Age' to 'Years'
data_renamed = data.rename(columns={'what is your visual acuity':'visual_acuity', 
                                    'What difficulties in seeing do u have': 'Vision_difficulties',
                                    'level of education': 'Education_level',
                                    'peripheral vision': 'Peripheral_vision',
                                    'gender': 'Gender',
                                    'disease progress degeneration': 'Degeneration',
                                    'age': 'Age',
                                    'modern or traditional technologies':'Technologies',
                                    'when do you have issues adjusting light': 'Adjusting_Light',
                                    'can you drive': 'Driving',
                                   'Unnamed: 25': 'Occupation',
                                    'Unnamed: 26': 'Disease',
                                   })
data_renamed
# Out:
#                        Timestamp visual_acuity        Vision_difficulties  \
# 0    2024/06/04 7:12:42 PM GMT+3           NaN                        NaN
# 1    2024/07/11 6:25:15 PM GMT+3           NaN                        NaN
# 2    2024/07/11 6:33:16 PM GMT+3           NaN                        NaN
# 3    2024/07/11 7:56:36 PM GMT+3           NaN                        NaN
# 4    2024/07/11 8:33:01 PM GMT+3           NaN                        NaN
# 5    2024/07/11 8:33:31 PM GMT+3           NaN                        NaN
# 6    2024/07/11 8:50:03 PM GMT+3           NaN                        NaN
# 7    2024/07/11 9:33:51 PM GMT+3           NaN                        NaN
# 8   2024/07/12 10:44:42 AM GMT+3           NaN                        NaN
# 9    2024/07/12 8:39:18 PM GMT+3           NaN                        NaN
# 10   2024/07/13 8:08:30 AM GMT+3           NaN                        NaN
# 11  2024/07/13 12:18:29 PM GMT+3           NaN                        NaN
# 12   2024/07/13 3:50:55 PM GMT+3           NaN                        NaN
# 13   2024/07/13 4:12:49 PM GMT+3           NaN                        NaN
# 14   2024/07/13 5:03:35 PM GMT+3           NaN                        NaN
# 15  2024/07/13 10:13:17 PM GMT+3           NaN                        NaN
# 16  2024/07/15 12:05:15 PM GMT+3           NaN                        NaN
# 17   2024/07/15 1:21:08 PM GMT+3           NaN                        NaN
# 18   2024/07/15 4:46:03 PM GMT+3           NaN                        NaN
# 19   2024/07/17 9:38:46 AM GMT+3           NaN                        NaN
# 20  2024/07/17 11:02:27 AM GMT+3           NaN                        NaN
# 21  2024/07/17 12:43:20 PM GMT+3           NaN                        NaN
# 22   2024/07/17 7:35:46 PM GMT+3           NaN                        NaN
# 23   2024/07/18 5:59:35 PM GMT+3           NaN                        NaN
# 24   2024/07/18 9:43:33 PM GMT+3           NaN                        NaN
# 25  2024/07/18 10:01:26 PM GMT+3           NaN                        NaN
# 26  2024/07/18 10:03:20 PM GMT+3           NaN                        NaN
# 27  2024/07/18 10:10:51 PM GMT+3           NaN                        NaN
# 28  2024/07/18 10:25:45 PM GMT+3           NaN                        NaN
# 29   2024/07/19 7:52:43 AM GMT+3           NaN                        NaN
# 30   2024/07/19 8:42:57 AM GMT+3           NaN                        NaN
# 31   2024/07/20 8:23:45 AM GMT+3           NaN                        NaN
# 32   2024/07/22 7:41:14 PM GMT+3           NaN                        NaN
# 33  2024/07/25 11:03:48 PM GMT+3           NaN                        NaN
# 34   2024/07/26 4:20:25 PM GMT+3           NaN                        NaN
# 35   2024/07/26 5:40:32 PM GMT+3           NaN                        NaN
# 36   2024/07/27 2:22:25 PM GMT+3           NaN                        NaN
# 37   2024/07/31 8:18:57 PM GMT+3           NaN                        NaN
# 38  2024/08/01 10:34:49 AM GMT+3           NaN                        NaN
# 39   2024/08/12 8:36:21 PM GMT+3           NaN                        NaN
# 40  2024/08/21 10:32:25 AM GMT+3        3 of 6                    reading
# 41   2024/08/23 4:05:56 PM GMT+3        2 of 6                    reading
# 42  2024/08/26 12:00:27 PM GMT+3        2 of 6          looking up a menu
# 43   2024/08/26 6:19:55 PM GMT+3        3 of 6                    reading
# 44   2024/08/26 6:41:47 PM GMT+3        3 of 6                    reading
# 45   2024/08/26 6:50:54 PM GMT+3        2 of 6                    reading
# 46   2024/08/26 7:07:59 PM GMT+3           NaN  reading;looking up a menu
# 47   2024/08/26 8:24:58 PM GMT+3        3 of 6                    reading
# 48   2024/08/26 8:51:07 PM GMT+3        1 of 6          looking up a menu
# 49  2024/08/28 10:29:36 AM GMT+3        1 of 6                    reading
# 50   2024/08/28 6:33:57 PM GMT+3        2 of 6                    reading
#
#                need          Peripheral_vision  Gender  \
# 0   assistive device                  Option 1     NaN
# 1                job                       NaN     NaN
# 2      work training                       NaN     NaN
# 3   assistive device                  Option 1     NaN
# 4   assistive device                  Option 1     NaN
# 5              other                       NaN     NaN
# 6      work training                       NaN     NaN
# 7   assistive device                  Option 1     NaN
# 8              other                  Option 1     NaN
# 9                NaN                       NaN     NaN
# 10  assistive device                  Option 1     NaN
# 11  assistive device                       NaN     NaN
# 12  assistive device                       NaN     NaN
# 13  assistive device                       NaN     NaN
# 14  assistive device                  Option 1     NaN
# 15  assistive device                  Option 1     NaN
# 16  assistive device                       NaN     NaN
# 17               NaN                       NaN     NaN
# 18  assistive device                  Option 1     NaN
# 19  assistive device                       NaN     NaN
# 20             other                       NaN     NaN
# 21  assistive device                       NaN     NaN
# 22  assistive device                       NaN     NaN
# 23  assistive device                       NaN     NaN
# 24  assistive device                  Option 1     NaN
# 25               job                  Option 1     NaN
# 26  assistive device                       NaN     NaN
# 27  assistive device                       NaN     NaN
# 28  assistive device                  Option 1     NaN
# 29  assistive device                  Option 1     NaN
# 30  assistive device                  Option 1     NaN
# 31             other                       NaN     NaN
# 32  assistive device                  Option 1     NaN
# 33               NaN                       NaN     NaN
# 34  assistive device                       NaN     NaN
# 35             other                       NaN     NaN
# 36  assistive device                       NaN     NaN
# 37               NaN                       NaN     NaN
# 38  assistive device                  Option 1     NaN
# 39  assistive device                  Option 1     NaN
# 40  assistive device         10 degrees  to 15     NaN
# 41  assistive device  15 degrees to 20 degrees     NaN
# 42  assistive device         10 degrees  to 15     NaN
# 43  assistive device         10 degrees  to 15     NaN
# 44  assistive device          20 degrees to 25     NaN
# 45  assistive device                       NaN     NaN
# 46             other                       NaN     NaN
# 47  assistive device                       NaN     NaN
# 48  assistive device         10 degrees  to 15     NaN
# 49  assistive device   5 degrees to 10 degrees     NaN
# 50  assistive device         10 degrees  to 15     NaN
#
#                                       Education_level  \
# 0                                 Bachelor Abschluss
# 1                 Bachelor's degree in Arts Education
# 2                                         University
# 3                                         University
# 4                                       Undergraduate
# 5      S.6/ Uganda Advanced Certificate of Education
# 6                                         University
# 7                                         University
# 8                                         University
# 9                 Faculty of Education and Humanities
# 10                                        University
# 11                                        University
# 12                                        University
# 13                                    Senior 6 level
# 14  Bachelor of Arts Education, history and Econom...
# 15          Year 4 Bachelor’s in Medicine and Surgery
# 16                                            Degree
# 17                           Currently at University
# 18                                        University
# 19                                             Degree
# 20                                        University
# 21                                            Degree
# 22                                        University
# 23                                  Bachelor's degree
# 24                                          Bachelors
# 25                                        University
# 26                                  Bachelor's degree
# 27                                        University
# 28                                  Bachelors degree
# 29                                         University
# 30                                            Degree
# 31                                           Tertiary
# 32                                             Year 2
# 33                                               UACE
# 34                                             DEGREE
# 35                                University student
# 36                                         Bachelors
# 37                                      Degree level
# 38                                 Bachelor's degree
# 39                                            Degree
# 40                                     Undergraduate
# 41               Bachelor degree Arts with Education
# 42                                        University
# 43                                                S.4
# 44                                            Deploma
# 45                                           Student
# 46                                       Institution
# 47                                          Tertiary
# 48                                        University
# 49                                             Degree
# 50                                            Degree
#
#    consent to share information with funders and research institutes  \
# 0                                       Yes I consent
# 1                                        I do consent
# 2                                          I consent
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                 NaN
# 10                          Yes, you have my consent
# 11    I Acola Gloria consent to share my information
# 12                                                Yes
# 13                                          Its fine
# 14  I KAMBALE CHANCE ACRAIT,I agree to share my bi...
# 15                                            Granted
# 16                                                NaN
# 17                                     Yes I consent
# 18                                           Consent
# 19                            Effect of bright light
# 20                                                Yes
# 21  I Atto lydia joyce consent to share my informa...
# 22         Problem of some reading assistance device.
# 23  I like to express my gratitude to you for your...
# 24                                                Yes
# 25                                                Yes
# 26                                            I agree
# 27                                             Agreed
# 28             Feel free to share information please
# 29  I Auma Mabruka Hamza consent to you my informa...
# 30                                    Consent granted
# 31                                         I consent
# 32                                                Yes
# 33                                                Yes
# 34  I Alum Elizabeth declare that the information ...
# 35                                            Granted
# 36                                                Yes
# 37                                                NaN
# 38  I Mwesigwa B Mayanja here by give my voluntary...
# 39                                       You are free
# 40  i Alex Ssekitto consent that i am to share my ...
# 41                                                NaN
# 42                                                NaN
# 43                                                Yes
# 44                                                yes
# 45                                               I do
# 46                                                NaN
# 47                                                NaN
# 48                                                Yes
# 49                    To find a  way of  helping me
# 50                                                Yes
#
#    challenges in job search and mobility  \
# 0                               Option 1
# 1                               Option 1
# 2                               Option 1
# 3                               Option 1
# 4                               Option 1
# 5                                    NaN
# 6                               Option 1
# 7                               Option 1
# 8                               Option 1
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                              Option 1
# 13                                   NaN
# 14                              Option 1
# 15                              Option 1
# 16                                   NaN
# 17                                   NaN
# 18                              Option 1
# 19                                   NaN
# 20                              Option 1
# 21                                   NaN
# 22                                   NaN
# 23                              Option 1
# 24                              Option 1
# 25                              Option 1
# 26                                   NaN
# 27                                   NaN
# 28                              Option 1
# 29                              Option 1
# 30                              Option 1
# 31                              Option 1
# 32                              Option 1
# 33                                   NaN
# 34                                   NaN
# 35                              Option 1
# 36                                   NaN
# 37                                   NaN
# 38                                   NaN
# 39                              Option 1
# 40                   inadequate exposure
# 41                 inadequate  education
# 42                   inadequate exposure
# 43                 inadequate  education
# 44                                   NaN
# 45                                   NaN
# 46                 inadequate  education
# 47                                   NaN
# 48                                   NaN
# 49                                   NaN
# 50            finding the right employer
#
#                                       Adjusting_Light  ...       Age  \
# 0                                                 NaN  ...  20 to 30
# 1                                                 NaN  ...  20 to 30
# 2                                                 NaN  ...  20 to 30
# 3                                                 NaN  ...  20 to 30
# 4                                                 NaN  ...  20 to 30
# 5                                                 NaN  ...  20 to 30
# 6                                            Student   ...  20 to 30
# 7                                                 Yes  ...  20 to 30
# 8                                                 NaN  ...  20 to 30
# 9                                                 NaN  ...  20 to 30
# 10                                                NaN  ...  20 to 30
# 11                                                NaN  ...  20 to 30
# 12                                                NaN  ...  20 to 30
# 13                                                NaN  ...  31 to 40
# 14  I face a problem with information access due t...  ...  20 to 30
# 15                                                NaN  ...  20 to 30
# 16                                                NaN  ...  20 to 30
# 17                                                NaN  ...  20 to 30
# 18                                                NaN  ...  20 to 30
# 19                                                NaN  ...  20 to 30
# 20                                                NaN  ...  20 to 30
# 21                                                NaN  ...  31 to 40
# 22                                                NaN  ...  20 to 30
# 23                    Corruption against the disabled  ...  20 to 30
# 24                                            At MUBS  ...  20 to 30
# 25                             Expecting to graduate   ...  20 to 30
# 26                                                NaN  ...  20 to 30
# 27                                                NaN  ...  20 to 30
# 28                                                NaN  ...  20 to 30
# 29               Bachelor degree in midwifery science  ...  20 to 30
# 30                                                NaN  ...  20 to 30
# 31  Student of public health at Lira university  L...  ...  20 to 30
# 32                                           Student   ...  20 to 30
# 33                                                NaN  ...  20 to 30
# 34                                                NaN  ...  20 to 30
# 35  The disease name is high myopia..plan =2.75 DS...  ...  20 to 30
# 36                                           Student   ...  20 to 30
# 37                                                NaN  ...  20 to 30
# 38                                                NaN  ...  20 to 30
# 39                                                NaN  ...  20 to 30
# 40                                     during the day  ...  20 to 30
# 41                                     during the day  ...  20 to 30
# 42                                     during the day  ...  20 to 30
# 43                            at night;during the day  ...  41 to 50
# 44                            at night;during the day  ...  41 to 50
# 45                            at night;during the day  ...  20 to 30
# 46                            at night;during the day  ...  31 to 40
# 47                                                NaN  ...  41 to 50
# 48                                                NaN  ...  20 to 30
# 49                                     during the day  ...  20 to 30
# 50                                     during the day  ...  20 to 30
#
#                          Name                             Email  \
# 0             Anita Atuheire              anita37desa@gmail.com
# 1              Sangalo Dianah          sangalodianah2@gmail.com
# 2           Atim Nelly Marie           nellymarieatim@gmail.com
# 3             Openda Hillary          opendahillary89@gmail.com
# 4           Kiwanda uthaifah       kiwandauthaifah483@gmail.com
# 5          Lamaro Edna Moreen            lamaroedna99@gmail.com
# 6                Ayudu Jesca               jescaayudu@gmail.com
# 7              Adiao Rebecca               beckyadiao@gmail.com
# 8              Amoding Babra           babraamoding34@gmail.com
# 9                 Apiyo concy           concyapiyo383@gmail.com
# 10        Shafik Nsabiyeera N       shafiknnsabiyeera@gmail.com
# 11              ACOLA GLORIA          gloriaacola2000@gmail.com
# 12         Nyikiriize Abaasa              abaasaban13@gmail.com
# 13                 Natukunda     prudencenatukunda870@gmail.com
# 14     KAMBALE CHANCE ACRAIT      kambalechanceacrait@gmail.com
# 15           Agenorwot Faith                  phayage@gmail.com
# 16                Aromo milly           aromomilly864@gmail.com
# 17      Ainembabazi Innocent    ainembabaziinnocent82@gmail.com
# 18         SSEGGANE GRACIOUS         gracioussseggane@gmail.com
# 19        Kasingabalya Andrew      kasingabalyaandrew@gmail.com
# 20         Acayo Alice Holga          aliceholgaacayo@gmail.com
# 21          Atto Lydia joyce              attolydia12@gmail.com
# 22              OPIO DESMOND            opiodesmond22@gmail.com
# 23                ASUTO RHODA             rhodaasuto6@gmail.com
# 24         CHEBET CHARITY JOY      chebetcharityjoy56@gmail.com
# 25           AGUTI JOY MERCY            joymercyaguti@gmail.com
# 26  NAMUTEBI PATIENCE KUTEESA  patiencekuteesanamtebi@gmail.com
# 27           Natukunda Peace             misspeace135@gmail.com
# 28            Aceng Patricia           acengpatricia2@gmail.com
# 29         Auma Mabruka Hamza            nabrukahamza@gmail.com
# 30         ATUHAIRWE HARRIET      atuhairweharriet681@gmail.com
# 31       Khanakwa  Voni Alice      vonialice.khanakwa@gmail.com
# 32            Namagembe Joan         joannamagembe487@gmail.com
# 33     Adyero Prudence Prima               adyerikj02@gmail.com
# 34             ALUM ELIZABETH        elizabethalum109@gmail.com
# 35   Akullu Immaculate Agang                agangimax@gmail.com
# 36           Letasi Prudence               tassiepipi@gmail.com
# 37            Kicarwot shalom          peaceshalom446@gmail.com
# 38         Mayanja B Mwesigwa           mayanjaburden@gmail.com
# 39              Masela Aggrey           maseraaggrey2@gmail.com
# 40             Ssekitto Alex            alexssekitto0@gmail.com
# 41      Masika Hidaya Yuwasi            hasashafords9@gmail.com
# 42       Nanyange Zebia Rona           2200801060@std.kyu.ac.ug
# 43           Theopista kagere              esther5205@yahoo.com
# 44          Damalie Ssengooba               damaliese@gmail.com
# 45             Isaac Mudduse                  sbud346@gmail.com
# 46              Muswa Esther             muswaesther6@gmail.com
# 47        Ssengooba Hezekiah               ssengoba61@gmail.com
# 48                    Mukwaya   geraldkabandagerald34@gmail.com
# 49              ADOCH  BRENDA           adochbrenda60@gmail.com
# 50            Mwase Abubakar          mwaseabubakar92@gmail.com
#
#                                               Address  \
# 0                               Schäufeleinstraße 26a
# 1                                        Bombo Kalule
# 2                            Currently in Nakasongola
# 3                    Ocwee memorial hostel, Gulu city
# 4                                              Gulu.
# 5      Gulu university, P.O.Box 166, Laroo, Gulu city
# 6                                             Dokolo
# 7                                    Gulu university
# 8                                             Soroti
# 9                                              Concy
# 10                                   Kawaala, Kampala
# 11            Forest cell, laroo division, Gulu City
# 12                                          Gulu city
# 13                                            Kabale
# 14                GULU UNIVERSITY in Northern Uganda
# 15                                Laroo, Gulu, Uganda
# 16                                         Obiya East
# 17                                               Gulu
# 18                                               Gulu
# 19                                   Gulu university
# 20                                   Gulu university
# 21       University forest, Laroo division, Gulu city
# 22                                              LIRA
# 23                                               GULU
# 24                                          Kapchorwa
# 25                                           Bukedea
# 26                                               Lira
# 27                                        Lira uganda
# 28                                   Lira University
# 29             Ayers village, Barapwo, Lira city west
# 30                                   Lira university
# 31                       Lira University- Lira Uganda
# 32                                     Wakiso kakiri
# 33                                   Lira university
# 34  TEYAO VILLAGE,OBER PARISH, BARR SUB COUNTY,LIR...
# 35                     Lira city west, Lira district
# 36                                   Lira university
# 37                                            Barapwo
# 38                                   Lira university
# 39                                    Lira university
# 40                     Kampala _ Makerere university
# 41                                    Kampala Uganda
# 42                                              Banda
# 43                                      Kira - wakisi
# 44                                          Namugongo
# 45                                         Namugongo
# 46                                          Kamwokya
# 47                                         Namugongo
# 48                                          Namugongo
# 49                                            Kireka
# 50                                     Iganga Uganda
#
#                Phone number  \
# 0                5218061474
# 1                 777744959
# 2                O760074203
# 3                 756998432
# 4                 759894923
# 5   0781940115 / 0743267013
# 6                 782199847
# 7                 786598787
# 8                 782994665
# 9                 789653560
# 10              2.56755E+11
# 11                786758216
# 12             0750 325237
# 13                773360163
# 14                756527867
# 15                781299110
# 16                776829413
# 17              2.56773E+11
# 18                751144453
# 19                788467710
# 20                783541383
# 21                770689840
# 22                770923009
# 23                773009342
# 24                765102557
# 25                788362771
# 26                751997972
# 27               -761314186
# 28                763225584
# 29                770718811
# 30              25656274824
# 31               07752423p7
# 32                705572681
# 33              2.56788E+11
# 34    0776489794/0752671164
# 35    0788643620/0706456530
# 36                777178605
# 37                787609631
# 38                771929407
# 39                781790176
# 40    0780445476/0706018253
# 41                761638832
# 42                780127284
# 43                785196622
# 44                703177238
# 45                766706493
# 46    0786423977/0705254863
# 47                759698461
# 48                700853149
# 49                740758125
# 50              2.56788E+11
#
#    Comments please add your measurements here from the doctors  \
# 0                                                 NaN
# 1                          Need your support and help
# 2   I thank you for this but please I would like t...
# 3                                               None
# 4   Disease condition is keratoconus with myopia.\...
# 5   I'm grateful for the work your doing to improv...
# 6   Thanks for recognizing people with special needs
# 7   I'm grateful to be part of this but I really n...
# 8                                                 NaN
# 9                                   Visual impairment
# 10  Much appreciation for all the efforts in ensur...
# 11       Thanks for the support you always give to us
# 12                                       No comments
# 13                                                NaN
# 14  I really appreciate your timely intervention,a...
# 15        Hope to get the necessary help, thank you.
# 16                                                NaN
# 17                          Am grateful and thankful
# 18                                                NaN
# 19                                                NaN
# 20                I have astigmatism as my eye defect
# 21            Thanks so much for always supporting us
# 22                                                NaN
# 23                                      Very grateful
# 24                               I feel so motivated
# 25                                     I am grateful
# 26                                                NaN
# 27            Will much more appreciate your support
# 28  I will be humbled when request is considered, ...
# 29  This a wonderful opportunity for us students w...
# 30           Your support will be highly appreciated
# 31                                         Thank you
# 32                  We are grateful for your support
# 33  It's a good program, the change brought by you...
# 34  I am a student offering bachelor of midwifery ...
# 35  Thanks so much for the initiative to distribut...
# 36  Thank you for the concern, I will be grateful ...
# 37                                           Awesome
# 38  Am really great full for this service and I re...
# 39                                               Fair
# 40  i will be very happy if i get lenses and glass...
# 41                                                  1
# 42                                  RE -2.00, LE-2.00
# 43                                                 -2
# 44                                            5/5 mor
# 45                                               0.25
# 46                           V SPH 1 6/6 LENS 5/5 MOR
# 47                                                 -2
# 48                                                 12
# 49                                                NaN
# 50         SPH     CYL    AXIS    ADD    AV\nRE -0...
#
#                                           Unnamed: 24  \
# 0                                            Stundent
# 1                                                 NaN
# 2                                            Teacher
# 3                                            Student
# 4                                            Student
# 5                                                 NaN
# 6                                            Student
# 7                                            Student
# 8                                    Business teacher
# 9                                                 NaN
# 10                                            Student
# 11                                           Student
# 12                                   Not yet employed
# 13                                         A student
# 14                                          Teaching
# 15                                            Student
# 16                                           Student
# 17                                           Student
# 18                                   Medical student
# 19                                           Student
# 20                                           Student
# 21                                                NaN
# 22                                                NaN
# 23                                            Student
# 24                                           Student
# 25  Undergraduate student (Bachelor's degree), wai...
# 26                                                NaN
# 27                                                NaN
# 28  I find hardship at school when using laptop, w...
# 29                                            Student
# 30                                           Student
# 31                                            Student
# 32                    Student at kyambogo university
# 33                                           Student
# 34                                                NaN
# 35                                            Student
# 36                                           Student
# 37                                           Student
# 38                                                NaN
# 39                                            Teacher
# 40  Nursing student at Makerere university in year...
# 41                                           Student
# 42                                                NaN
# 43                                         House wife
# 44                                            teacher
# 45                                                 No
# 46                                           Student
# 47                                     Self employed
# 48                                                NaN
# 49                                            Student
# 50                                           Student
#
#                                    Occupation                    Disease  \
# 0                                    Student            retinal dystophy
# 1                                     Teacher       retinitis pigmentosa
# 2                                     Teacher       retinitis pigmentosa
# 3                                    Student        retinitis pigmentosa
# 4                                     Student                        NaN
# 5                                     Student                        NaN
# 6                                    Student        retinitis pigmentosa
# 7                                    Student            retinal dystophy
# 8                                     Student                        NaN
# 9                                         NaN                        NaN
# 10                           Medical student                         NaN
# 11                                   Student                    glaucoma
# 12                                   Student                    glaucoma
# 13                                   Student        retinitis pigmentosa
# 14                                  Teaching            retinal dystophy
# 15                                    Student           retinal dystophy
# 16                                        NaN           retinal dystophy
# 17                                   Student                         NaN
# 18                           Medical student                         NaN
# 19                                   Student                         NaN
# 20                                   Student                         NaN
# 21                                    Student                   glaucoma
# 22                                    Student                        NaN
# 23                                  A student       macular degeneration
# 24                                    Student                   glaucoma
# 25  Undergraduate student (Bachelor's degree)                        NaN
# 26                                    Student                        NaN
# 27                                    Student                        NaN
# 28                                   Student        macular degeneration
# 29                                    Student                        NaN
# 30                                    Student       macular degeneration
# 31                                    Student       macular degeneration
# 32            Student at kyambogo university                         NaN
# 33                                   Student                         NaN
# 34                                    STUDENT                        NaN
# 35                                    Student                        NaN
# 36                                   Student                    glaucoma
# 37                                   Student                         NaN
# 38                                   Student                    glaucoma
# 39                                   Teacher        retinitis pigmentosa
# 40          student in Fourth year doing BNUR  glaucoma;retinal dystophy
# 41                                   Student            retinal dystophy
# 42                                   Student        retinitis pigmentosa
# 43                                 House wife                 choromedia
# 44                                    teacher                   glaucoma
# 45                                         No                        NaN
# 46                                   Student        macular degeneration
# 47                             Self employed                         NaN
# 48                                   Student                  choromedia
# 49                                    Student                   glaucoma
# 50                                   Student        macular degeneration
#
#                  Unnamed: 27
# 0                      other
# 1        impairement  degree
# 2       visual acuity degree
# 3       visual acuity degree
# 4       visual acuity degree
# 5   peripheral vision degree
# 6        impairement  degree
# 7        impairement  degree
# 8       visual acuity degree
# 9       visual acuity degree
# 10       impairement  degree
# 11       impairement  degree
# 12      visual acuity degree
# 13      visual acuity degree
# 14       impairement  degree
# 15                     other
# 16                     other
# 17       impairement  degree
# 18       impairement  degree
# 19                       NaN
# 20                     other
# 21       impairement  degree
# 22       impairement  degree
# 23       impairement  degree
# 24      visual acuity degree
# 25       impairement  degree
# 26      visual acuity degree
# 27      visual acuity degree
# 28                     other
# 29       impairement  degree
# 30       impairement  degree
# 31                     other
# 32      visual acuity degree
# 33                       NaN
# 34                       NaN
# 35      visual acuity degree
# 36      visual acuity degree
# 37                       NaN
# 38                     other
# 39      visual acuity degree
# 40       impairement  degree
# 41       impairement  degree
# 42       impairement  degree
# 43      visual acuity degree
# 44      visual acuity degree
# 45                       NaN
# 46  peripheral vision degree
# 47                       NaN
# 48  peripheral vision degree
# 49  peripheral vision degree
# 50       impairement  degree
#
# [51 rows x 28 columns]

# %%
# If the column has leading/trailing spaces, strip them:
data_renamed.columns = data_renamed.columns.str.strip()

# %%
# Selecting specific columns to create a sub-dataset
sub_dataset = data_renamed[['need', 'Education_level', 'Age', 'Occupation', 'Disease']]
# Display the first few rows of the sub-dataset
print(sub_dataset)
# Out:
#                 need                                    Education_level  \
# 0   assistive device                                Bachelor Abschluss
# 1                job                Bachelor's degree in Arts Education
# 2      work training                                        University
# 3   assistive device                                        University
# 4   assistive device                                      Undergraduate
# 5              other     S.6/ Uganda Advanced Certificate of Education
# 6      work training                                        University
# 7   assistive device                                        University
# 8              other                                        University
# 9                NaN                Faculty of Education and Humanities
# 10  assistive device                                        University
# 11  assistive device                                        University
# 12  assistive device                                        University
# 13  assistive device                                    Senior 6 level
# 14  assistive device  Bachelor of Arts Education, history and Econom...
# 15  assistive device          Year 4 Bachelor’s in Medicine and Surgery
# 16  assistive device                                            Degree
# 17               NaN                           Currently at University
# 18  assistive device                                        University
# 19  assistive device                                             Degree
# 20             other                                        University
# 21  assistive device                                            Degree
# 22  assistive device                                        University
# 23  assistive device                                  Bachelor's degree
# 24  assistive device                                          Bachelors
# 25               job                                        University
# 26  assistive device                                  Bachelor's degree
# 27  assistive device                                        University
# 28  assistive device                                  Bachelors degree
# 29  assistive device                                         University
# 30  assistive device                                            Degree
# 31             other                                           Tertiary
# 32  assistive device                                             Year 2
# 33               NaN                                               UACE
# 34  assistive device                                             DEGREE
# 35             other                                University student
# 36  assistive device                                         Bachelors
# 37               NaN                                      Degree level
# 38  assistive device                                 Bachelor's degree
# 39  assistive device                                            Degree
# 40  assistive device                                     Undergraduate
# 41  assistive device               Bachelor degree Arts with Education
# 42  assistive device                                        University
# 43  assistive device                                                S.4
# 44  assistive device                                            Deploma
# 45  assistive device                                           Student
# 46             other                                       Institution
# 47  assistive device                                          Tertiary
# 48  assistive device                                        University
# 49  assistive device                                             Degree
# 50  assistive device                                            Degree
#
#          Age                                 Occupation  \
# 0   20 to 30                                   Student
# 1   20 to 30                                    Teacher
# 2   20 to 30                                    Teacher
# 3   20 to 30                                   Student
# 4   20 to 30                                    Student
# 5   20 to 30                                    Student
# 6   20 to 30                                   Student
# 7   20 to 30                                   Student
# 8   20 to 30                                    Student
# 9   20 to 30                                        NaN
# 10  20 to 30                           Medical student
# 11  20 to 30                                   Student
# 12  20 to 30                                   Student
# 13  31 to 40                                   Student
# 14  20 to 30                                  Teaching
# 15  20 to 30                                    Student
# 16  20 to 30                                        NaN
# 17  20 to 30                                   Student
# 18  20 to 30                           Medical student
# 19  20 to 30                                   Student
# 20  20 to 30                                   Student
# 21  31 to 40                                    Student
# 22  20 to 30                                    Student
# 23  20 to 30                                  A student
# 24  20 to 30                                    Student
# 25  20 to 30  Undergraduate student (Bachelor's degree)
# 26  20 to 30                                    Student
# 27  20 to 30                                    Student
# 28  20 to 30                                   Student
# 29  20 to 30                                    Student
# 30  20 to 30                                    Student
# 31  20 to 30                                    Student
# 32  20 to 30            Student at kyambogo university
# 33  20 to 30                                   Student
# 34  20 to 30                                    STUDENT
# 35  20 to 30                                    Student
# 36  20 to 30                                   Student
# 37  20 to 30                                   Student
# 38  20 to 30                                   Student
# 39  20 to 30                                   Teacher
# 40  20 to 30          student in Fourth year doing BNUR
# 41  20 to 30                                   Student
# 42  20 to 30                                   Student
# 43  41 to 50                                 House wife
# 44  41 to 50                                    teacher
# 45  20 to 30                                         No
# 46  31 to 40                                   Student
# 47  41 to 50                             Self employed
# 48  20 to 30                                   Student
# 49  20 to 30                                    Student
# 50  20 to 30                                   Student
#
#                       Disease
# 0            retinal dystophy
# 1        retinitis pigmentosa
# 2        retinitis pigmentosa
# 3        retinitis pigmentosa
# 4                         NaN
# 5                         NaN
# 6        retinitis pigmentosa
# 7            retinal dystophy
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                   glaucoma
# 12                   glaucoma
# 13       retinitis pigmentosa
# 14           retinal dystophy
# 15           retinal dystophy
# 16           retinal dystophy
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                   glaucoma
# 22                        NaN
# 23       macular degeneration
# 24                   glaucoma
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28       macular degeneration
# 29                        NaN
# 30       macular degeneration
# 31       macular degeneration
# 32                        NaN
# 33                        NaN
# 34                        NaN
# 35                        NaN
# 36                   glaucoma
# 37                        NaN
# 38                   glaucoma
# 39       retinitis pigmentosa
# 40  glaucoma;retinal dystophy
# 41           retinal dystophy
# 42       retinitis pigmentosa
# 43                 choromedia
# 44                   glaucoma
# 45                        NaN
# 46       macular degeneration
# 47                        NaN
# 48                 choromedia
# 49                   glaucoma
# 50       macular degeneration

# %%
# Print unique levels for each column
for column in sub_dataset.columns:
    print(f"Levels for column '{column}':")
    print(sub_dataset[column].unique())
    print()
# Out:
# Levels for column 'need':
# ['assistive device' 'job' 'work training' 'other' nan]
#
# Levels for column 'Education_level':
# ['Bachelor Abschluss ' "Bachelor's degree in Arts Education" 'University '
#  'Undergraduate' 'S.6/ Uganda Advanced Certificate of Education '
#  'Faculty of Education and Humanities' 'Senior 6 level '
#  'Bachelor of Arts Education, history and Economics '
#  'Year 4 Bachelor’s in Medicine and Surgery' 'Degree '
#  'Currently at University ' 'Degree' "Bachelor's degree" 'Bachelors'
#  'Bachelors degree ' 'University' 'Tertiary' 'Year 2' 'UACE' 'DEGREE'
#  'University student ' 'Bachelors ' 'Degree level ' "Bachelor's degree "
#  'Undergraduate ' 'Bachelor degree Arts with Education ' 'S.4' 'Deploma'
#  'Student ' 'Institution ' 'Tertiary ']
#
# Levels for column 'Age':
# ['20 to 30' '31 to 40' '41 to 50']
#
# Levels for column 'Occupation':
# ['Student ' 'Teacher' 'Student' nan 'Medical student ' 'Teaching '
#  'A student' "Undergraduate student (Bachelor's degree)"
#  'Student at kyambogo university ' 'STUDENT' 'Teacher '
#  'student in Fourth year doing BNUR' 'House wife' 'teacher' 'No'
#  'Self employed ']
#
# Levels for column 'Disease':
# ['retinal dystophy' 'retinitis pigmentosa' nan 'glaucoma'
#  'macular degeneration' 'glaucoma;retinal dystophy' 'choromedia']

# %%
#map needs to 
need_mapping = {
    'assistive device': 'Assistive Device',
    'job': 'Job',
    'work training': 'Skills Training',
    'other': 'Other',
    np.nan: 'Unknown'
}
sub_dataset.loc[:, 'need'] = sub_dataset['need'].map(need_mapping)

# %%
# Define numeric mapping for age categories
age_numeric_mapping = {
    '20 to 30': 1,
    '31 to 40': 2,
    '41 to 50': 3
}

# Apply numeric mapping to the 'age' column
sub_dataset.loc[:, 'Age'] = sub_dataset['Age'].map(age_numeric_mapping)

# %%
print(sub_dataset)
# Out:
#                 need                                    Education_level Age  \
# 0   Assistive Device                                Bachelor Abschluss    1
# 1                Job                Bachelor's degree in Arts Education   1
# 2    Skills Training                                        University    1
# 3   Assistive Device                                        University    1
# 4   Assistive Device                                      Undergraduate   1
# 5              Other     S.6/ Uganda Advanced Certificate of Education    1
# 6    Skills Training                                        University    1
# 7   Assistive Device                                        University    1
# 8              Other                                        University    1
# 9            Unknown                Faculty of Education and Humanities   1
# 10  Assistive Device                                        University    1
# 11  Assistive Device                                        University    1
# 12  Assistive Device                                        University    1
# 13  Assistive Device                                    Senior 6 level    2
# 14  Assistive Device  Bachelor of Arts Education, history and Econom...   1
# 15  Assistive Device          Year 4 Bachelor’s in Medicine and Surgery   1
# 16  Assistive Device                                            Degree    1
# 17           Unknown                           Currently at University    1
# 18  Assistive Device                                        University    1
# 19  Assistive Device                                             Degree   1
# 20             Other                                        University    1
# 21  Assistive Device                                            Degree    2
# 22  Assistive Device                                        University    1
# 23  Assistive Device                                  Bachelor's degree   1
# 24  Assistive Device                                          Bachelors   1
# 25               Job                                        University    1
# 26  Assistive Device                                  Bachelor's degree   1
# 27  Assistive Device                                        University    1
# 28  Assistive Device                                  Bachelors degree    1
# 29  Assistive Device                                         University   1
# 30  Assistive Device                                            Degree    1
# 31             Other                                           Tertiary   1
# 32  Assistive Device                                             Year 2   1
# 33           Unknown                                               UACE   1
# 34  Assistive Device                                             DEGREE   1
# 35             Other                                University student    1
# 36  Assistive Device                                         Bachelors    1
# 37           Unknown                                      Degree level    1
# 38  Assistive Device                                 Bachelor's degree    1
# 39  Assistive Device                                            Degree    1
# 40  Assistive Device                                     Undergraduate    1
# 41  Assistive Device               Bachelor degree Arts with Education    1
# 42  Assistive Device                                        University    1
# 43  Assistive Device                                                S.4   3
# 44  Assistive Device                                            Deploma   3
# 45  Assistive Device                                           Student    1
# 46             Other                                       Institution    2
# 47  Assistive Device                                          Tertiary    3
# 48  Assistive Device                                        University    1
# 49  Assistive Device                                             Degree   1
# 50  Assistive Device                                            Degree    1
#
#                                    Occupation                    Disease
# 0                                    Student            retinal dystophy
# 1                                     Teacher       retinitis pigmentosa
# 2                                     Teacher       retinitis pigmentosa
# 3                                    Student        retinitis pigmentosa
# 4                                     Student                        NaN
# 5                                     Student                        NaN
# 6                                    Student        retinitis pigmentosa
# 7                                    Student            retinal dystophy
# 8                                     Student                        NaN
# 9                                         NaN                        NaN
# 10                           Medical student                         NaN
# 11                                   Student                    glaucoma
# 12                                   Student                    glaucoma
# 13                                   Student        retinitis pigmentosa
# 14                                  Teaching            retinal dystophy
# 15                                    Student           retinal dystophy
# 16                                        NaN           retinal dystophy
# 17                                   Student                         NaN
# 18                           Medical student                         NaN
# 19                                   Student                         NaN
# 20                                   Student                         NaN
# 21                                    Student                   glaucoma
# 22                                    Student                        NaN
# 23                                  A student       macular degeneration
# 24                                    Student                   glaucoma
# 25  Undergraduate student (Bachelor's degree)                        NaN
# 26                                    Student                        NaN
# 27                                    Student                        NaN
# 28                                   Student        macular degeneration
# 29                                    Student                        NaN
# 30                                    Student       macular degeneration
# 31                                    Student       macular degeneration
# 32            Student at kyambogo university                         NaN
# 33                                   Student                         NaN
# 34                                    STUDENT                        NaN
# 35                                    Student                        NaN
# 36                                   Student                    glaucoma
# 37                                   Student                         NaN
# 38                                   Student                    glaucoma
# 39                                   Teacher        retinitis pigmentosa
# 40          student in Fourth year doing BNUR  glaucoma;retinal dystophy
# 41                                   Student            retinal dystophy
# 42                                   Student        retinitis pigmentosa
# 43                                 House wife                 choromedia
# 44                                    teacher                   glaucoma
# 45                                         No                        NaN
# 46                                   Student        macular degeneration
# 47                             Self employed                         NaN
# 48                                   Student                  choromedia
# 49                                    Student                   glaucoma
# 50                                   Student        macular degeneration

# %%
# Define the refined mapping
level_of_education_mapping = {
    'Bachelor Abschluss ': 'University',
    "Bachelor's degree in Arts Education": 'University',
    'University ': 'University',
    'Undergraduate': 'University',
    'S.6/ Uganda Advanced Certificate of Education ': 'Advanced Secondary',
    'Faculty of Education and Humanities': 'University',
    'Senior 6 level ': 'Advanced Secondary',
    'Bachelor of Arts Education, history and Economics ': 'University',
    'Year 4 Bachelor’s in Medicine and Surgery': 'University',
    'Degree ': 'University',
    'Currently at University ': 'University',
    'Degree': 'University',
    "Bachelor's degree": 'University',
    'Bachelors': 'University',
    'Bachelors degree ': 'University',
    'University': 'University',
    'Tertiary': 'Tertiary',
    'Year 2': 'University',
    'UACE': 'Advanced Secondary',
    'DEGREE': 'University',
    'University student ': 'University',
    'Bachelors ': 'University',
    'Degree level ': 'University',
    "Bachelor's degree ": 'University',
    'Undergraduate ': 'University',
    'Bachelor degree Arts with Education ': 'University',
    'S.4': 'Ordinary Secondary',
    'Deploma': 'Diploma Level',
    'Student ': 'University',
    'Institution ': 'Diploma Level',
    'Tertiary ': 'Tertiary',
    np.nan: 'Unknown'
}

# Apply the mapping
sub_dataset['Education_level'] = sub_dataset['Education_level'].map(level_of_education_mapping)
# Out:
# C:\Users\JULIANA\AppData\Local\Temp\ipykernel_20328\463383663.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_dataset['Education_level'] = sub_dataset['Education_level'].map(level_of_education_mapping)

# %%
print(sub_dataset)
# Out:
#                 need     Education_level Age  \
# 0   Assistive Device          University   1
# 1                Job          University   1
# 2    Skills Training          University   1
# 3   Assistive Device          University   1
# 4   Assistive Device          University   1
# 5              Other  Advanced Secondary   1
# 6    Skills Training          University   1
# 7   Assistive Device          University   1
# 8              Other          University   1
# 9            Unknown          University   1
# 10  Assistive Device          University   1
# 11  Assistive Device          University   1
# 12  Assistive Device          University   1
# 13  Assistive Device  Advanced Secondary   2
# 14  Assistive Device          University   1
# 15  Assistive Device          University   1
# 16  Assistive Device          University   1
# 17           Unknown          University   1
# 18  Assistive Device          University   1
# 19  Assistive Device          University   1
# 20             Other          University   1
# 21  Assistive Device          University   2
# 22  Assistive Device          University   1
# 23  Assistive Device          University   1
# 24  Assistive Device          University   1
# 25               Job          University   1
# 26  Assistive Device          University   1
# 27  Assistive Device          University   1
# 28  Assistive Device          University   1
# 29  Assistive Device          University   1
# 30  Assistive Device          University   1
# 31             Other            Tertiary   1
# 32  Assistive Device          University   1
# 33           Unknown  Advanced Secondary   1
# 34  Assistive Device          University   1
# 35             Other          University   1
# 36  Assistive Device          University   1
# 37           Unknown          University   1
# 38  Assistive Device          University   1
# 39  Assistive Device          University   1
# 40  Assistive Device          University   1
# 41  Assistive Device          University   1
# 42  Assistive Device          University   1
# 43  Assistive Device  Ordinary Secondary   3
# 44  Assistive Device       Diploma Level   3
# 45  Assistive Device          University   1
# 46             Other       Diploma Level   2
# 47  Assistive Device            Tertiary   3
# 48  Assistive Device          University   1
# 49  Assistive Device          University   1
# 50  Assistive Device          University   1
#
#                                    Occupation                    Disease
# 0                                    Student            retinal dystophy
# 1                                     Teacher       retinitis pigmentosa
# 2                                     Teacher       retinitis pigmentosa
# 3                                    Student        retinitis pigmentosa
# 4                                     Student                        NaN
# 5                                     Student                        NaN
# 6                                    Student        retinitis pigmentosa
# 7                                    Student            retinal dystophy
# 8                                     Student                        NaN
# 9                                         NaN                        NaN
# 10                           Medical student                         NaN
# 11                                   Student                    glaucoma
# 12                                   Student                    glaucoma
# 13                                   Student        retinitis pigmentosa
# 14                                  Teaching            retinal dystophy
# 15                                    Student           retinal dystophy
# 16                                        NaN           retinal dystophy
# 17                                   Student                         NaN
# 18                           Medical student                         NaN
# 19                                   Student                         NaN
# 20                                   Student                         NaN
# 21                                    Student                   glaucoma
# 22                                    Student                        NaN
# 23                                  A student       macular degeneration
# 24                                    Student                   glaucoma
# 25  Undergraduate student (Bachelor's degree)                        NaN
# 26                                    Student                        NaN
# 27                                    Student                        NaN
# 28                                   Student        macular degeneration
# 29                                    Student                        NaN
# 30                                    Student       macular degeneration
# 31                                    Student       macular degeneration
# 32            Student at kyambogo university                         NaN
# 33                                   Student                         NaN
# 34                                    STUDENT                        NaN
# 35                                    Student                        NaN
# 36                                   Student                    glaucoma
# 37                                   Student                         NaN
# 38                                   Student                    glaucoma
# 39                                   Teacher        retinitis pigmentosa
# 40          student in Fourth year doing BNUR  glaucoma;retinal dystophy
# 41                                   Student            retinal dystophy
# 42                                   Student        retinitis pigmentosa
# 43                                 House wife                 choromedia
# 44                                    teacher                   glaucoma
# 45                                         No                        NaN
# 46                                   Student        macular degeneration
# 47                             Self employed                         NaN
# 48                                   Student                  choromedia
# 49                                    Student                   glaucoma
# 50                                   Student        macular degeneration

# %%
#need,disease
# Define the refined mapping
level_of_education_mapping = {
    'Bachelor Abschluss ': 'University',
    "Bachelor's degree in Arts Education": 'University',
    'University ': 'University',
    'Undergraduate': 'University',
    'S.6/ Uganda Advanced Certificate of Education ': 'Advanced Secondary',
    'Faculty of Education and Humanities': 'University',
    'Senior 6 level ': 'Advanced Secondary',
    'Bachelor of Arts Education, history and Economics ': 'University',
    'Year 4 Bachelor’s in Medicine and Surgery': 'University',
    'Degree ': 'University',
    'Currently at University ': 'University',
    'Degree': 'University',
    "Bachelor's degree": 'University',
    'Bachelors': 'University',
    'Bachelors degree ': 'University',
    'University': 'University',
    'Tertiary': 'Tertiary',
    'Year 2': 'University',
    'UACE': 'Advanced Secondary',
    'DEGREE': 'University',
    'University student ': 'University',
    'Bachelors ': 'University',
    'Degree level ': 'University',
    "Bachelor's degree ": 'University',
    'Undergraduate ': 'University',
    'Bachelor degree Arts with Education ': 'University',
    'S.4': 'Ordinary Secondary',
    'Deploma': 'Diploma Level',
    'Student ': 'University',
    'Institution ': 'Diploma Level',
    'Tertiary ': 'Tertiary',
    np.nan: 'Unknown'
}

# Apply the mapping
sub_dataset['Education_level'] = sub_dataset['Education_level'].map(level_of_education_mapping)
# Out:
# C:\Users\JULIANA\AppData\Local\Temp\ipykernel_20328\2631626453.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_dataset['Education_level'] = sub_dataset['Education_level'].map(level_of_education_mapping)

# %%
#ocupation,isease
# Define the refined mapping
level_of_education_mapping = {
    'Bachelor Abschluss ': 'University',
    "Bachelor's degree in Arts Education": 'University',
    'University ': 'University',
    'Undergraduate': 'University',
    'S.6/ Uganda Advanced Certificate of Education ': 'Advanced Secondary',
    'Faculty of Education and Humanities': 'University',
    'Senior 6 level ': 'Advanced Secondary',
    'Bachelor of Arts Education, history and Economics ': 'University',
    'Year 4 Bachelor’s in Medicine and Surgery': 'University',
    'Degree ': 'University',
    'Currently at University ': 'University',
    'Degree': 'University',
    "Bachelor's degree": 'University',
    'Bachelors': 'University',
    'Bachelors degree ': 'University',
    'University': 'University',
    'Tertiary': 'Tertiary',
    'Year 2': 'University',
    'UACE': 'Advanced Secondary',
    'DEGREE': 'University',
    'University student ': 'University',
    'Bachelors ': 'University',
    'Degree level ': 'University',
    "Bachelor's degree ": 'University',
    'Undergraduate ': 'University',
    'Bachelor degree Arts with Education ': 'University',
    'S.4': 'Ordinary Secondary',
    'Deploma': 'Diploma Level',
    'Student ': 'University',
    'Institution ': 'Diploma Level',
    'Tertiary ': 'Tertiary',
    np.nan: 'Unknown'
}

# Apply the mapping
sub_dataset['Education_level'] = sub_dataset['Education_level'].map(level_of_education_mapping)
# Out:
# C:\Users\JULIANA\AppData\Local\Temp\ipykernel_20328\4202433503.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_dataset['Education_level'] = sub_dataset['Education_level'].map(level_of_education_mapping)

# %%
#occupation and  disease
# Define the refined mapping
level_of_Occupation_mapping = {
    "student":'Student',
    "teacher":'Teacher',
    "Medical student":'Student',
    
    'other': 'Other',
    
    np.nan: 'Unknown'
}

# Apply the mapping
sub_dataset['Occupation'] = sub_dataset['Occupation'].map(level_of_Occupation_mapping)
# Out:
# C:\Users\JULIANA\AppData\Local\Temp\ipykernel_20328\2187692847.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_dataset['Occupation'] = sub_dataset['Occupation'].map(level_of_Occupation_mapping)

# %%
print(sub_dataset)
# Out:
#                 need Education_level Age Occupation                    Disease
# 0   Assistive Device      University   1        NaN           retinal dystophy
# 1                Job      University   1        NaN       retinitis pigmentosa
# 2    Skills Training      University   1        NaN       retinitis pigmentosa
# 3   Assistive Device      University   1        NaN       retinitis pigmentosa
# 4   Assistive Device      University   1        NaN                        NaN
# 5              Other         Unknown   1        NaN                        NaN
# 6    Skills Training      University   1        NaN       retinitis pigmentosa
# 7   Assistive Device      University   1        NaN           retinal dystophy
# 8              Other      University   1        NaN                        NaN
# 9            Unknown      University   1    Unknown                        NaN
# 10  Assistive Device      University   1        NaN                        NaN
# 11  Assistive Device      University   1        NaN                   glaucoma
# 12  Assistive Device      University   1        NaN                   glaucoma
# 13  Assistive Device         Unknown   2        NaN       retinitis pigmentosa
# 14  Assistive Device      University   1        NaN           retinal dystophy
# 15  Assistive Device      University   1        NaN           retinal dystophy
# 16  Assistive Device      University   1    Unknown           retinal dystophy
# 17           Unknown      University   1        NaN                        NaN
# 18  Assistive Device      University   1        NaN                        NaN
# 19  Assistive Device      University   1        NaN                        NaN
# 20             Other      University   1        NaN                        NaN
# 21  Assistive Device      University   2        NaN                   glaucoma
# 22  Assistive Device      University   1        NaN                        NaN
# 23  Assistive Device      University   1        NaN       macular degeneration
# 24  Assistive Device      University   1        NaN                   glaucoma
# 25               Job      University   1        NaN                        NaN
# 26  Assistive Device      University   1        NaN                        NaN
# 27  Assistive Device      University   1        NaN                        NaN
# 28  Assistive Device      University   1        NaN       macular degeneration
# 29  Assistive Device      University   1        NaN                        NaN
# 30  Assistive Device      University   1        NaN       macular degeneration
# 31             Other        Tertiary   1        NaN       macular degeneration
# 32  Assistive Device      University   1        NaN                        NaN
# 33           Unknown         Unknown   1        NaN                        NaN
# 34  Assistive Device      University   1        NaN                        NaN
# 35             Other      University   1        NaN                        NaN
# 36  Assistive Device      University   1        NaN                   glaucoma
# 37           Unknown      University   1        NaN                        NaN
# 38  Assistive Device      University   1        NaN                   glaucoma
# 39  Assistive Device      University   1        NaN       retinitis pigmentosa
# 40  Assistive Device      University   1        NaN  glaucoma;retinal dystophy
# 41  Assistive Device      University   1        NaN           retinal dystophy
# 42  Assistive Device      University   1        NaN       retinitis pigmentosa
# 43  Assistive Device         Unknown   3        NaN                 choromedia
# 44  Assistive Device         Unknown   3    Teacher                   glaucoma
# 45  Assistive Device      University   1        NaN                        NaN
# 46             Other         Unknown   2        NaN       macular degeneration
# 47  Assistive Device        Tertiary   3        NaN                        NaN
# 48  Assistive Device      University   1        NaN                 choromedia
# 49  Assistive Device      University   1        NaN                   glaucoma
# 50  Assistive Device      University   1        NaN       macular degeneration

# %%
#occupation and  disease
# Define the refined mapping
level_of_Disease_mapping = {
    'retinitis pigmentosa': 'Legally Blind',
    'glaucoma': 'Blind',
    'macular degeneration': 'Visual Impairment',
    'choromedia': 'Severally Blind',
   # 'retinal dystrophy': 'HouseWife',
    'other': 'Other',
    # np.nan: 'Unknown',
     np.nan: 'Unknown'
}

# Apply the mapping
sub_dataset['Disease'] = sub_dataset['Disease'].map(level_of_Disease_mapping)
# Out:
# C:\Users\JULIANA\AppData\Local\Temp\ipykernel_20328\3084686073.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_dataset['Disease'] = sub_dataset['Disease'].map(level_of_Disease_mapping)

# %%
print(sub_dataset)
# Out:
#                 need Education_level Age Occupation            Disease
# 0   Assistive Device      University   1        NaN                NaN
# 1                Job      University   1        NaN      Legally Blind
# 2    Skills Training      University   1        NaN      Legally Blind
# 3   Assistive Device      University   1        NaN      Legally Blind
# 4   Assistive Device      University   1        NaN            Unknown
# 5              Other         Unknown   1        NaN            Unknown
# 6    Skills Training      University   1        NaN      Legally Blind
# 7   Assistive Device      University   1        NaN                NaN
# 8              Other      University   1        NaN            Unknown
# 9            Unknown      University   1    Unknown            Unknown
# 10  Assistive Device      University   1        NaN            Unknown
# 11  Assistive Device      University   1        NaN              Blind
# 12  Assistive Device      University   1        NaN              Blind
# 13  Assistive Device         Unknown   2        NaN      Legally Blind
# 14  Assistive Device      University   1        NaN                NaN
# 15  Assistive Device      University   1        NaN                NaN
# 16  Assistive Device      University   1    Unknown                NaN
# 17           Unknown      University   1        NaN            Unknown
# 18  Assistive Device      University   1        NaN            Unknown
# 19  Assistive Device      University   1        NaN            Unknown
# 20             Other      University   1        NaN            Unknown
# 21  Assistive Device      University   2        NaN              Blind
# 22  Assistive Device      University   1        NaN            Unknown
# 23  Assistive Device      University   1        NaN  Visual Impairment
# 24  Assistive Device      University   1        NaN              Blind
# 25               Job      University   1        NaN            Unknown
# 26  Assistive Device      University   1        NaN            Unknown
# 27  Assistive Device      University   1        NaN            Unknown
# 28  Assistive Device      University   1        NaN  Visual Impairment
# 29  Assistive Device      University   1        NaN            Unknown
# 30  Assistive Device      University   1        NaN  Visual Impairment
# 31             Other        Tertiary   1        NaN  Visual Impairment
# 32  Assistive Device      University   1        NaN            Unknown
# 33           Unknown         Unknown   1        NaN            Unknown
# 34  Assistive Device      University   1        NaN            Unknown
# 35             Other      University   1        NaN            Unknown
# 36  Assistive Device      University   1        NaN              Blind
# 37           Unknown      University   1        NaN            Unknown
# 38  Assistive Device      University   1        NaN              Blind
# 39  Assistive Device      University   1        NaN      Legally Blind
# 40  Assistive Device      University   1        NaN                NaN
# 41  Assistive Device      University   1        NaN                NaN
# 42  Assistive Device      University   1        NaN      Legally Blind
# 43  Assistive Device         Unknown   3        NaN    Severally Blind
# 44  Assistive Device         Unknown   3    Teacher              Blind
# 45  Assistive Device      University   1        NaN            Unknown
# 46             Other         Unknown   2        NaN  Visual Impairment
# 47  Assistive Device        Tertiary   3        NaN            Unknown
# 48  Assistive Device      University   1        NaN    Severally Blind
# 49  Assistive Device      University   1        NaN              Blind
# 50  Assistive Device      University   1        NaN  Visual Impairment
